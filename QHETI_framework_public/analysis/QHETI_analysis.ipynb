# %% [markdown]
# # Load Packages

# %%
# ===============================
# File Paths
# ===============================

# ===============================
# Configs From QHETI_HTL_ind.ipynb
# ===============================
FIRST_EPOCHS = ""
LAST_EPOCHS = ""
BATCH_SIZE = ""
NUM_LAYERS_UNFROZEN_POP = ""
NUM_LAYERS_UNFROZEN_IND = []

# %% [markdown]
# # 1. Model Evaluation Aggregation and Plotting

# %%
def plot_metric_by_model_and_layer(df, metric, title=None):
    """
    Create box plots of a given evaluation metric for each model type,
    separated by number of unfrozen layers.

    NOTE: Proprietary visualization style and mapping logic are hidden.
    """
    # NOTE: Proprietary seaborn style partially hidden
    # NOTE: Proprietary model name mapping (e.g., DecisionTree -> DT) partially hidden
    # NOTE: Proprietary FacetGrid setup and customization partially hidden

    # # Set seaborn style
    # sns.set_theme(style="whitegrid", font_scale=0.9)

    # # Map long model names to short ones
    # model_name_map = {
    #     'DecisionTree': 'DT',
    #     'K-NN': 'KNN',
    #     'LogisticRegression': 'LR',
    #     'NaiveBayes': 'NB',
    #     'SVM': 'SVM'
    # }

    # # Create a copy and map model names
    # df = df.copy()
    # df['Model Type Short'] = df['Model Type'].map(model_name_map)

    # # Create FacetGrid
    # g = sns.FacetGrid(
    #     df,
    #     col="Number of Layers Unfrozen",
    #     col_wrap=3,
    #     height=4,
    #     sharey=True,
    #     margin_titles=True
    # )

    # # Draw boxplots
    # g.map_dataframe(
    #     sns.boxplot,
    #     x="Model Type Short",
    #     y=metric,
    #     order=['DT', 'KNN', 'LR', 'NB', 'SVM']
    # )

    # # Customize each subplot
    # for ax in g.axes.flatten():
    #     ax.set_xticks(range(5))
    #     ax.set_xticklabels(['DT', 'KNN', 'LR', 'NB', 'SVM'], fontsize=9)
    #     ax.tick_params(axis='x', labelrotation=0)
    #     ax.xaxis.set_tick_params(which='both', labelbottom=True)
    #     ax.set_ylim(0, 1)
    #     ax.set_yticks(np.arange(0.0, 1.1, 0.1))  # y-ticks at 0.1 intervals

    # # Set titles and labels
    # g.set_titles(col_template="Number of Layers Unfrozen: {col_name}")
    # g.set_axis_labels("Model Type", metric)

    # if title:
    #     plt.subplots_adjust(top=0.88)
    #     g.fig.suptitle(title, fontsize=14)

    # plt.subplots_adjust(hspace=0.5)
    # plt.show()

# %%
# Load the data
import pandas as pd

# ---------------------------------------------------------
# Step 1: Load evaluation results (file path proprietary)
# ---------------------------------------------------------
# NOTE: Proprietary file path and data structure hidden
# df = pd.read_csv("path/to/full_evaluation_data.csv")
df = pd.DataFrame()  # Placeholder

# ---------------------------------------------------------
# Step 2: Extract derived fields from version tags
# ---------------------------------------------------------
# NOTE: Proprietary parsing logic hidden
# df['Number of Layers Unfrozen'] = ...
# df['Patient ID'] = ...
# df['Model Type'] = ...

# ---------------------------------------------------------
# Step 3: Aggregate metrics by layer, patient, and model
# ---------------------------------------------------------
# NOTE: Proprietary aggregation logic hidden
# grouped = df.groupby(['Number of Layers Unfrozen', 'Patient ID', 'Model Type'])
# avg_metrics = grouped.mean(numeric_only=True).reset_index()

avg_metrics = pd.DataFrame()  # Placeholder

# ---------------------------------------------------------
# Step 4: Reorder columns (example logic hidden)
# ---------------------------------------------------------
# NOTE: Proprietary column ordering logic hidden
# ordered_cols = ...
# avg_metrics = avg_metrics[ordered_cols]

# ---------------------------------------------------------
# Step 5: Save or visualize results
# ---------------------------------------------------------
# NOTE: Proprietary plotting logic hidden
# plot_metric_by_model_and_layer(avg_metrics, "Sensitivity/Recall", title="Sensitivity/Recall by Model and Layer")

display(avg_metrics)
# avg_metrics.to_csv('averaged_results.csv', index=False)

# %% [markdown]
# # 2. Evaluation Metrics by Layer Unfrozen: Boxplots and CSV Export

# %%
def plot_single_layer_boxplot(df, path, metric, layer_num, title=None):
    """
    Plot a single box plot of model types for one specific layer group.

    NOTE: Proprietary visualization style and file naming logic are hidden.
    """
    # NOTE: Proprietary seaborn styling, model mapping, and figure setup hidden
    # Example placeholder:
    # fig, ax = plt.subplots()
    # sns.boxplot(data=df, x="Model Type", y=metric, ax=ax)
    # ax.set_title(title or f"{metric} by Model Type (Layer {layer_num})")
    # plt.savefig(f"{path}/{layer_num}_Layer_Unfrozen_{metric}_boxplot.png")
    pass  # Placeholder (proprietary implementation not shown)


# NOTE: Proprietary logic for looping over layers and saving CSVs hidden
# layer_group_dfs = {}
# metric_to_plot = "Sensitivity/Recall"
# for layer in sorted(avg_metrics['Number of Layers Unfrozen'].unique()):
#     layer_df = avg_metrics[avg_metrics['Number of Layers Unfrozen'] == layer]
#     plot_single_layer_boxplot(layer_df, path=EVALUATION_METRIC_SAVE_PATH, metric=metric_to_plot, layer_num=layer)
#     layer_group_dfs[layer] = layer_df
#     layer_df.to_csv(f"{EVALUATION_METRIC_SAVE_PATH}/{layer}_Layer_Unfrozen_Analysis.csv", index=False)
#     display(layer_df)
